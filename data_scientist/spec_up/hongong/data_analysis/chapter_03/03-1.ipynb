# %%
import pandas as pd

ns_df = pd.read_csv("data/ns_202104.csv", low_memory=False)

ns_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
ns_df.dropna(axis=1, how='all', inplace=True)

ns_df
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# 1       9791190123969            NaN  NaN  NaN      NaN     1     0
# 2       9788968332982            NaN  NaN  NaN      NaN     1     0
# 3       9788970759906            NaN  NaN  NaN      NaN     1     0
# 4       9788934990833            NaN  NaN  NaN      NaN     1     0
# ...               ...            ...  ...  ...      ...   ...   ...
# 401677  9788977352971  9788977352988  NaN    3  811.608     1     0
# 401678  9788985367448  9788985367424  NaN    2   688.04     1     0
# 401679  9788937401596  9788937401589  NaN    2    813.6     1     0
# 401680  9788947700368  9788947700405  NaN    3   809.05     2     0
# 401681  9788970610092  9788970610092    0    1    814.6     0     0
#
#               등록일자
# 0       2021-03-19
# 1       2021-03-19
# 2       2021-03-19
# 3       2021-03-19
# 4       2021-03-19
# ...            ...
# 401677  1970-01-01
# 401678  1970-01-01
# 401679  1970-01-01
# 401680  1970-01-01
# 401681  1970-01-01
#
# [401682 rows x 13 columns]

# %%
sum(ns_df.duplicated())
# Out:
# 0

# %%
sum(ns_df.duplicated(['도서명', '저자', 'ISBN']))
# Out:
# 22096

# %%
dup_rows = ns_df.duplicated(subset=['도서명', '저자', 'ISBN'], keep=False)
ns_book3 = ns_df[dup_rows]
ns_book3.head()
# Out:
#       번호                  도서명                 저자           출판사  발행년도  \
# 109  110                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 110  111                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 111  112  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 112  113  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 113  114                 스토너   존 윌리엄스 지음 ;김승욱 옮김  RHK(알에이치코리아)  2021
#
#               ISBN        세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 109  9788970129815  9788970129808    0    1  843.6     1     0  2021-03-12
# 110  9788970129822  9788970129808    0    2  843.6     1     0  2021-03-12
# 111  9788937479953            NaN    0  NaN  813.7     1     0  2021-03-12
# 112  9788937479953            NaN    0  NaN  813.7     1     1  2021-03-12
# 113  9788925538297            NaN    0  NaN  843.5     1     0  2021-03-12

# %%
count_df = ns_df[['도서명', '저자', 'ISBN', '권', '대출건수']]

# %%
loan_count = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False).sum()
loan_count.head()
# Out:
#                                                                                            대출건수
# 도서명                                            저자                       ISBN          권
# (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN    38
# (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    10
# (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     4
# (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     3
# ,에게                                            이기린(이진희)                 9791196137014 NaN     0

# %%
dup_rows = ns_df.duplicated(subset=['도서명', '저자', 'ISBN', '권'])
unique_rows = ~dup_rows
ns_book3 = ns_df[unique_rows].copy()

# %%
dup_rows
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 401677    False
# 401678    False
# 401679     True
# 401680    False
# 401681     True
# Length: 401682, dtype: bool

# %%
unique_rows
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 401677     True
# 401678     True
# 401679    False
# 401680     True
# 401681    False
# Length: 401682, dtype: bool

# %%
ns_book3
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401673  401674            소설의 사회사 비교론            조동일 지음  지식산업사  2001
# 401676  401677                    큰오빠            박정근 지음  우리문학사  1998
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# 1       9791190123969            NaN  NaN  NaN      NaN     1     0
# 2       9788968332982            NaN  NaN  NaN      NaN     1     0
# 3       9788970759906            NaN  NaN  NaN      NaN     1     0
# 4       9788934990833            NaN  NaN  NaN      NaN     1     0
# ...               ...            ...  ...  ...      ...   ...   ...
# 401673  9788942340262  9788942300365  NaN    3    809.3     1     0
# 401676  9788974231323  9788974231309  NaN    2    813.6     2     0
# 401677  9788977352971  9788977352988  NaN    3  811.608     1     0
# 401678  9788985367448  9788985367424  NaN    2   688.04     1     0
# 401680  9788947700368  9788947700405  NaN    3   809.05     2     0
#
#               등록일자
# 0       2021-03-19
# 1       2021-03-19
# 2       2021-03-19
# 3       2021-03-19
# 4       2021-03-19
# ...            ...
# 401673  1970-01-01
# 401676  1970-01-01
# 401677  1970-01-01
# 401678  1970-01-01
# 401680  1970-01-01
#
# [384591 rows x 13 columns]

# %%
sum(ns_book3.duplicated(subset=['도서명', '저자', 'ISBN', '권']))
# Out:
# 0

# %%
sum(ns_df.duplicated(subset=['도서명', '저자', 'ISBN', '권']))
# Out:
# 17091

# %%
ns_book3.set_index(['도서명', '저자', 'ISBN', '권'], inplace=True)
ns_book3
# Out:
#                                                               번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN       1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN       2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN       3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN       4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN       5    김영사  2021
# ...                                                          ...    ...   ...
# 소설의 사회사 비교론           조동일 지음           9788942340262 3    401674  지식산업사  2001
# 큰오빠                   박정근 지음           9788974231323 2    401677  우리문학사  1998
# 韓國現代詩大系               채만묵 編著           9788977352971 3    401678  한국문화사  1996
# 뉴 웨이브                 제임스 모나코 지음       9788985367448 2    401679    한나래  1996
# 독일 문학과 세계 문학          吳漢鎭 編著           9788947700368 3    401681     벽호  1995
#
#                                                                 세트 ISBN 부가기호  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN            NaN  NaN
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN            NaN  NaN
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN            NaN  NaN
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN            NaN  NaN
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN            NaN  NaN
# ...                                                                 ...  ...
# 소설의 사회사 비교론           조동일 지음           9788942340262 3    9788942300365  NaN
# 큰오빠                   박정근 지음           9788974231323 2    9788974231309  NaN
# 韓國現代詩大系               채만묵 編著           9788977352971 3    9788977352988  NaN
# 뉴 웨이브                 제임스 모나코 지음       9788985367448 2    9788985367424  NaN
# 독일 문학과 세계 문학          吳漢鎭 編著           9788947700368 3    9788947700405  NaN
#
#                                                            주제분류번호  도서권수  대출건수  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN      NaN     1     0
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN      NaN     1     0
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN      NaN     1     0
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN      NaN     1     0
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN      NaN     1     0
# ...                                                           ...   ...   ...
# 소설의 사회사 비교론           조동일 지음           9788942340262 3      809.3     1     0
# 큰오빠                   박정근 지음           9788974231323 2      813.6     2     0
# 韓國現代詩大系               채만묵 編著           9788977352971 3    811.608     1     0
# 뉴 웨이브                 제임스 모나코 지음       9788985367448 2     688.04     1     0
# 독일 문학과 세계 문학          吳漢鎭 編著           9788947700368 3     809.05     2     0
#
#                                                                 등록일자
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN  2021-03-19
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN  2021-03-19
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN  2021-03-19
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN  2021-03-19
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN  2021-03-19
# ...                                                              ...
# 소설의 사회사 비교론           조동일 지음           9788942340262 3    1970-01-01
# 큰오빠                   박정근 지음           9788974231323 2    1970-01-01
# 韓國現代詩大系               채만묵 編著           9788977352971 3    1970-01-01
# 뉴 웨이브                 제임스 모나코 지음       9788985367448 2    1970-01-01
# 독일 문학과 세계 문학          吳漢鎭 編著           9788947700368 3    1970-01-01
#
# [384591 rows x 9 columns]

# %%
loan_count
# Out:
#                                                                                             대출건수
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN    38
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    10
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     4
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     3
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     0
# ...                                                                                          ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN     0
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN     0
#                                                 NaN                      9788971990155 NaN     2
#                                                                          9788972803997 NaN     0
#                                                                          9788973561537 NaN     0
#
# [384591 rows x 1 columns]

# %%
# loan_count와 ns_book3의 인덱스를 정렬
loan_count = loan_count.sort_index()
ns_book3 = ns_book3.sort_index()

# 정렬된 상태에서 업데이트

ns_book3.update(loan_count)
ns_book3
# Out:
# /var/folders/j6/vc6mjcjd2yqghkgbv6fptp0r0000gn/T/ipykernel_3761/1610871852.py:7: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ns_book3.update(loan_count)
#                                                                                                 번호  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN  196447
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN  228738
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN  208220
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN   90468
#  ,에게                                            이기린(이진희)                 9791196137014 NaN   32496
# ...                                                                                            ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN  370878
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN  370795
#                                                 NaN                      9788971990155 NaN  317397
#                                                                          9788972803997 NaN  391425
#                                                                          9788973561537 NaN  392882
#
#                                                                                                       출판사  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN            글로벌
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN           청림아이
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN  영잘원(ETS BANK)
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN  Bansok(반석출판사)
#  ,에게                                            이기린(이진희)                 9791196137014 NaN            포지션
# ...                                                                                                   ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN            로드북
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN            學古房
#                                                 NaN                      9788971990155 NaN            돌베개
#                                                                          9788972803997 NaN             大林
#                                                                          9788973561537 NaN        한국노동연구원
#
#                                                                                             발행년도  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN  2011
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN  2009
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN  2009
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN  2016
#  ,에게                                            이기린(이진희)                 9791196137014 NaN  2017
# ...                                                                                          ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN  2017
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN  2017
#                                                 NaN                      9788971990155 NaN  1993
#                                                                          9788972803997 NaN  1997
#                                                                          9788973561537 NaN  1997
#
#                                                                                            세트 ISBN  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN     NaN
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN     NaN
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     NaN
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     NaN
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     NaN
# ...                                                                                            ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN     NaN
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN     NaN
#                                                 NaN                      9788971990155 NaN     NaN
#                                                                          9788972803997 NaN     NaN
#                                                                          9788973561537 NaN     NaN
#
#                                                                                            부가기호  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN    1
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    7
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN    1
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN    1
#  ,에게                                            이기린(이진희)                 9791196137014 NaN  NaN
# ...                                                                                         ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN  NaN
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN  NaN
#                                                 NaN                      9788971990155 NaN    0
#                                                                          9788972803997 NaN    9
#                                                                          9788973561537 NaN    9
#
#                                                                                               주제분류번호  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN   004.582
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    321.55
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN       747
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN    739.82
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     811.7
# ...                                                                                              ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN       NaN
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN       NaN
#                                                 NaN                      9788971990155 NaN     166.9
#                                                                          9788972803997 NaN  569.9863
#                                                                          9788973561537 NaN       336
#
#                                                                                             도서권수  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN     1
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN     1
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     2
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     2
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     1
# ...                                                                                          ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN     1
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN     1
#                                                 NaN                      9788971990155 NaN     1
#                                                                          9788972803997 NaN     1
#                                                                          9788973561537 NaN     1
#
#                                                                                             대출건수  \
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN    38
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    10
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     4
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     3
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     0
# ...                                                                                          ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN     0
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN     0
#                                                 NaN                      9788971990155 NaN     2
#                                                                          9788972803997 NaN     0
#                                                                          9788973561537 NaN     0
#
#                                                                                                   등록일자
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN  2011-03-10
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN  2009-07-20
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN  2010-07-14
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN  2016-06-22
#  ,에게                                            이기린(이진희)                 9791196137014 NaN  2019-05-17
# ...                                                                                                ...
# NaN                                             히라야마 쯔요시 외 5인            9788997924318 NaN  2004-10-19
#                                                 ？德峰(Yang Defeng)         9788960716957 NaN  2004-10-19
#                                                 NaN                      9788971990155 NaN  2005-10-31
#                                                                          9788972803997 NaN  1970-01-01
#                                                                          9788973561537 NaN  1970-01-01
#
# [384591 rows x 9 columns]

# %%
ns_book4 = ns_book3.reset_index()
ns_book4
# Out:
#                                                     도서명  \
# 0                 (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기
# 1                                      (맨처음 배우는) 세상의 직업
# 2        (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편
# 3                        (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음
# 4                                                   ,에게
# ...                                                 ...
# 384586                                              NaN
# 384587                                              NaN
# 384588                                              NaN
# 384589                                              NaN
# 384590                                              NaN
#
#                               저자           ISBN    권      번호            출판사  \
# 0                         김상현 지음  9788955025637  NaN  196447            글로벌
# 1       엘레오노라 바르소티 글 ·그림 ;김태은 옮김  9788992924146  NaN  228738           청림아이
# 2                      JD Kim 지음  9788993466089  NaN  208220  영잘원(ETS BANK)
# 3                     FL4U컨텐츠 지음  9788971728000  NaN   90468  Bansok(반석출판사)
# 4                       이기린(이진희)  9791196137014  NaN   32496            포지션
# ...                          ...            ...  ...     ...            ...
# 384586             히라야마 쯔요시 외 5인  9788997924318  NaN  370878            로드북
# 384587          ？德峰(Yang Defeng)  9788960716957  NaN  370795            學古房
# 384588                       NaN  9788971990155  NaN  317397            돌베개
# 384589                       NaN  9788972803997  NaN  391425             大林
# 384590                       NaN  9788973561537  NaN  392882        한국노동연구원
#
#         발행년도 세트 ISBN 부가기호    주제분류번호  도서권수  대출건수        등록일자
# 0       2011     NaN    1   004.582     1    38  2011-03-10
# 1       2009     NaN    7    321.55     1    10  2009-07-20
# 2       2009     NaN    1       747     2     4  2010-07-14
# 3       2016     NaN    1    739.82     2     3  2016-06-22
# 4       2017     NaN  NaN     811.7     1     0  2019-05-17
# ...      ...     ...  ...       ...   ...   ...         ...
# 384586  2017     NaN  NaN       NaN     1     0  2004-10-19
# 384587  2017     NaN  NaN       NaN     1     0  2004-10-19
# 384588  1993     NaN    0     166.9     1     2  2005-10-31
# 384589  1997     NaN    9  569.9863     1     0  1970-01-01
# 384590  1997     NaN    9       336     1     0  1970-01-01
#
# [384591 rows x 13 columns]

# %%
sum(ns_book4['대출건수'] > 100)
# Out:
# 2550

# %%
ns_book4
# Out:
#                                                     도서명  \
# 0                 (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기
# 1                                      (맨처음 배우는) 세상의 직업
# 2        (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편
# 3                        (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음
# 4                                                   ,에게
# ...                                                 ...
# 384586                                              NaN
# 384587                                              NaN
# 384588                                              NaN
# 384589                                              NaN
# 384590                                              NaN
#
#                               저자           ISBN    권      번호            출판사  \
# 0                         김상현 지음  9788955025637  NaN  196447            글로벌
# 1       엘레오노라 바르소티 글 ·그림 ;김태은 옮김  9788992924146  NaN  228738           청림아이
# 2                      JD Kim 지음  9788993466089  NaN  208220  영잘원(ETS BANK)
# 3                     FL4U컨텐츠 지음  9788971728000  NaN   90468  Bansok(반석출판사)
# 4                       이기린(이진희)  9791196137014  NaN   32496            포지션
# ...                          ...            ...  ...     ...            ...
# 384586             히라야마 쯔요시 외 5인  9788997924318  NaN  370878            로드북
# 384587          ？德峰(Yang Defeng)  9788960716957  NaN  370795            學古房
# 384588                       NaN  9788971990155  NaN  317397            돌베개
# 384589                       NaN  9788972803997  NaN  391425             大林
# 384590                       NaN  9788973561537  NaN  392882        한국노동연구원
#
#         발행년도 세트 ISBN 부가기호    주제분류번호  도서권수  대출건수        등록일자
# 0       2011     NaN    1   004.582     1    38  2011-03-10
# 1       2009     NaN    7    321.55     1    10  2009-07-20
# 2       2009     NaN    1       747     2     4  2010-07-14
# 3       2016     NaN    1    739.82     2     3  2016-06-22
# 4       2017     NaN  NaN     811.7     1     0  2019-05-17
# ...      ...     ...  ...       ...   ...   ...         ...
# 384586  2017     NaN  NaN       NaN     1     0  2004-10-19
# 384587  2017     NaN  NaN       NaN     1     0  2004-10-19
# 384588  1993     NaN    0     166.9     1     2  2005-10-31
# 384589  1997     NaN    9  569.9863     1     0  1970-01-01
# 384590  1997     NaN    9       336     1     0  1970-01-01
#
# [384591 rows x 13 columns]

# %%
ns_df
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# 1       9791190123969            NaN  NaN  NaN      NaN     1     0
# 2       9788968332982            NaN  NaN  NaN      NaN     1     0
# 3       9788970759906            NaN  NaN  NaN      NaN     1     0
# 4       9788934990833            NaN  NaN  NaN      NaN     1     0
# ...               ...            ...  ...  ...      ...   ...   ...
# 401677  9788977352971  9788977352988  NaN    3  811.608     1     0
# 401678  9788985367448  9788985367424  NaN    2   688.04     1     0
# 401679  9788937401596  9788937401589  NaN    2    813.6     1     0
# 401680  9788947700368  9788947700405  NaN    3   809.05     2     0
# 401681  9788970610092  9788970610092    0    1    814.6     0     0
#
#               등록일자
# 0       2021-03-19
# 1       2021-03-19
# 2       2021-03-19
# 3       2021-03-19
# 4       2021-03-19
# ...            ...
# 401677  1970-01-01
# 401678  1970-01-01
# 401679  1970-01-01
# 401680  1970-01-01
# 401681  1970-01-01
#
# [401682 rows x 13 columns]

# %%
ns_book4 = ns_book4[ns_df.columns]
ns_book4
# Out:
#             번호                                              도서명  \
# 0       196447            (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기
# 1       228738                                 (맨처음 배우는) 세상의 직업
# 2       208220   (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편
# 3        90468                   (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음
# 4        32496                                              ,에게
# ...        ...                                              ...
# 384586  370878                                              NaN
# 384587  370795                                              NaN
# 384588  317397                                              NaN
# 384589  391425                                              NaN
# 384590  392882                                              NaN
#
#                               저자            출판사  발행년도           ISBN 세트 ISBN  \
# 0                         김상현 지음            글로벌  2011  9788955025637     NaN
# 1       엘레오노라 바르소티 글 ·그림 ;김태은 옮김           청림아이  2009  9788992924146     NaN
# 2                      JD Kim 지음  영잘원(ETS BANK)  2009  9788993466089     NaN
# 3                     FL4U컨텐츠 지음  Bansok(반석출판사)  2016  9788971728000     NaN
# 4                       이기린(이진희)            포지션  2017  9791196137014     NaN
# ...                          ...            ...   ...            ...     ...
# 384586             히라야마 쯔요시 외 5인            로드북  2017  9788997924318     NaN
# 384587          ？德峰(Yang Defeng)            學古房  2017  9788960716957     NaN
# 384588                       NaN            돌베개  1993  9788971990155     NaN
# 384589                       NaN             大林  1997  9788972803997     NaN
# 384590                       NaN        한국노동연구원  1997  9788973561537     NaN
#
#        부가기호    권    주제분류번호  도서권수  대출건수        등록일자
# 0         1  NaN   004.582     1    38  2011-03-10
# 1         7  NaN    321.55     1    10  2009-07-20
# 2         1  NaN       747     2     4  2010-07-14
# 3         1  NaN    739.82     2     3  2016-06-22
# 4       NaN  NaN     811.7     1     0  2019-05-17
# ...     ...  ...       ...   ...   ...         ...
# 384586  NaN  NaN       NaN     1     0  2004-10-19
# 384587  NaN  NaN       NaN     1     0  2004-10-19
# 384588    0  NaN     166.9     1     2  2005-10-31
# 384589    9  NaN  569.9863     1     0  1970-01-01
# 384590    9  NaN       336     1     0  1970-01-01
#
# [384591 rows x 13 columns]

# %%
ns_book4.to_csv("data/ns_book4.csv", index=False)

# %%
def data_cleaning(filename):
    """
    남산 도서관 장서 CSV 데이터 전처리 함수
    :param filename: CSV 파일 이름
    """
    # 파일을 데이터프레임으로 읽는다.
    ns_df = pd.read_csv(f'data/{filename}', low_memory=False)
    
    # NaN인 열을 삭제
    ns_book = ns_df.dropna(axis=1, how='all')
    
    # 대출 건수를 합치기 위해 필요한 행만 추출하여 count_df 데이터프레임 생성
    count_df = ns_book[['도서명', '저자', 'ISBN', '권', '대출건수']]
    
    # 도서명, 저자, ISBN, 권을 기준으로 대출건수를 groupby
    loan_count = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False).sum()
    
    # 원본 데이터프레임에서 중복된 행을 제외하고, 고유한 행만 추출 후 복사
    dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN', '권'])
    unique_rows = ~dup_rows
    ns_book3 = ns_book[unique_rows].copy()
    
    # 도서명, 저자, ISBN, 권을 인덱스로 설정
    ns_book3.set_index(['도서명', '저자', 'ISBN', '권'], inplace=True)
    
   # loan_count와 ns_book3의 인덱스를 정렬
    loan_count = loan_count.sort_index()
    ns_book3 = ns_book3.sort_index()

    # 정렬된 상태에서 업데이트
    ns_book3.update(loan_count)
    
    # 인덱스 재설정
    ns_book4 = ns_book3.reset_index()
    
    # 원본 데이터프레임의 열 순서로 변경
    ns_book4 = ns_book4[ns_book.columns]
    return ns_book4

# %%
new_ns_book4 = data_cleaning('ns_202104.csv')
ns_book4.equals(new_ns_book4)
# Out:
# /var/folders/j6/vc6mjcjd2yqghkgbv6fptp0r0000gn/T/ipykernel_3761/3646823537.py:31: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ns_book3.update(loan_count)
# True

# %%
new_ns_book4
# Out:
#             번호                                              도서명  \
# 0       196447            (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기
# 1       228738                                 (맨처음 배우는) 세상의 직업
# 2       208220   (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편
# 3        90468                   (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음
# 4        32496                                              ,에게
# ...        ...                                              ...
# 384586  370878                                              NaN
# 384587  370795                                              NaN
# 384588  317397                                              NaN
# 384589  391425                                              NaN
# 384590  392882                                              NaN
#
#                               저자            출판사  발행년도           ISBN 세트 ISBN  \
# 0                         김상현 지음            글로벌  2011  9788955025637     NaN
# 1       엘레오노라 바르소티 글 ·그림 ;김태은 옮김           청림아이  2009  9788992924146     NaN
# 2                      JD Kim 지음  영잘원(ETS BANK)  2009  9788993466089     NaN
# 3                     FL4U컨텐츠 지음  Bansok(반석출판사)  2016  9788971728000     NaN
# 4                       이기린(이진희)            포지션  2017  9791196137014     NaN
# ...                          ...            ...   ...            ...     ...
# 384586             히라야마 쯔요시 외 5인            로드북  2017  9788997924318     NaN
# 384587          ？德峰(Yang Defeng)            學古房  2017  9788960716957     NaN
# 384588                       NaN            돌베개  1993  9788971990155     NaN
# 384589                       NaN             大林  1997  9788972803997     NaN
# 384590                       NaN        한국노동연구원  1997  9788973561537     NaN
#
#        부가기호    권    주제분류번호  도서권수  대출건수        등록일자
# 0         1  NaN   004.582     1    38  2011-03-10
# 1         7  NaN    321.55     1    10  2009-07-20
# 2         1  NaN       747     2     4  2010-07-14
# 3         1  NaN    739.82     2     3  2016-06-22
# 4       NaN  NaN     811.7     1     0  2019-05-17
# ...     ...  ...       ...   ...   ...         ...
# 384586  NaN  NaN       NaN     1     0  2004-10-19
# 384587  NaN  NaN       NaN     1     0  2004-10-19
# 384588    0  NaN     166.9     1     2  2005-10-31
# 384589    9  NaN  569.9863     1     0  1970-01-01
# 384590    9  NaN       336     1     0  1970-01-01
#
# [384591 rows x 13 columns]

# %%
ns_book4
# Out:
#             번호                                              도서명  \
# 0       196447            (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기
# 1       228738                                 (맨처음 배우는) 세상의 직업
# 2       208220   (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편
# 3        90468                   (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음
# 4        32496                                              ,에게
# ...        ...                                              ...
# 384586  370878                                              NaN
# 384587  370795                                              NaN
# 384588  317397                                              NaN
# 384589  391425                                              NaN
# 384590  392882                                              NaN
#
#                               저자            출판사  발행년도           ISBN 세트 ISBN  \
# 0                         김상현 지음            글로벌  2011  9788955025637     NaN
# 1       엘레오노라 바르소티 글 ·그림 ;김태은 옮김           청림아이  2009  9788992924146     NaN
# 2                      JD Kim 지음  영잘원(ETS BANK)  2009  9788993466089     NaN
# 3                     FL4U컨텐츠 지음  Bansok(반석출판사)  2016  9788971728000     NaN
# 4                       이기린(이진희)            포지션  2017  9791196137014     NaN
# ...                          ...            ...   ...            ...     ...
# 384586             히라야마 쯔요시 외 5인            로드북  2017  9788997924318     NaN
# 384587          ？德峰(Yang Defeng)            學古房  2017  9788960716957     NaN
# 384588                       NaN            돌베개  1993  9788971990155     NaN
# 384589                       NaN             大林  1997  9788972803997     NaN
# 384590                       NaN        한국노동연구원  1997  9788973561537     NaN
#
#        부가기호    권    주제분류번호  도서권수  대출건수        등록일자
# 0         1  NaN   004.582     1    38  2011-03-10
# 1         7  NaN    321.55     1    10  2009-07-20
# 2         1  NaN       747     2     4  2010-07-14
# 3         1  NaN    739.82     2     3  2016-06-22
# 4       NaN  NaN     811.7     1     0  2019-05-17
# ...     ...  ...       ...   ...   ...         ...
# 384586  NaN  NaN       NaN     1     0  2004-10-19
# 384587  NaN  NaN       NaN     1     0  2004-10-19
# 384588    0  NaN     166.9     1     2  2005-10-31
# 384589    9  NaN  569.9863     1     0  1970-01-01
# 384590    9  NaN       336     1     0  1970-01-01
#
# [384591 rows x 13 columns]
