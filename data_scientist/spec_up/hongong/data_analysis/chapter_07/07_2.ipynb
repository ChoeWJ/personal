# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
ns_book7 = pd.read_csv("data/ns_book7.csv", low_memory=False)

ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
train_set, test_set = train_test_split(ns_book7, random_state=42)

# %%
print(len(train_set), len(test_set))
# Out:
# 282577 94193

# %%
X_train = train_set[['도서권수']]
y_train = train_set['대출건수']

print(X_train.shape, y_train.shape)
# Out:
# (282577, 1) (282577,)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test = test_set[['도서권수']]
y_test = test_set['대출건수']

lr.score(X_test, y_test)
# Out:
# 0.10025676249337057

# %%
lr.fit(y_train.to_frame(), y_train)
lr.score(y_test.to_frame(), y_test)
# Out:
# 1.0

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [1.] -1.2665424264923786e-12

# %%
# 절편 추가 (X 데이터에 상수항 추가)
X = sm.add_constant(X_train)

# OLS 회귀 모델 생성 및 학습
model = sm.OLS(y_train, X).fit()

# 결과 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   대출건수   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                 3.174e+04
# Date:                Mon, 27 Jan 2025   Prob (F-statistic):               0.00
# Time:                        11:03:29   Log-Likelihood:            -1.2242e+06
# No. Observations:              282577   AIC:                         2.448e+06
# Df Residuals:                  282575   BIC:                         2.448e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.1455      0.090    -35.060      0.000      -3.321      -2.970
# 도서권수          12.8765      0.072    178.162      0.000      12.735      13.018
# ==============================================================================
# Omnibus:                   436839.632   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1802144313.442
# Skew:                           9.000   Prob(JB):                         0.00
# Kurtosis:                     393.816   Cond. No.                         5.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
borrow_mean = ns_book7['대출건수'].mean()

y_train_c = y_train > borrow_mean
y_test_c = y_test > borrow_mean

# %%
logr = LogisticRegression()
logr.fit(X_train, y_train_c)
logr.score(X_test, y_test_c)
# Out:
# 0.7106154385145393

# %%
y_test_c.value_counts()
# Out:
# 대출건수
# False    65337
# True     28856
# Name: count, dtype: int64

# %%
from sklearn.dummy import DummyClassifier

dc = DummyClassifier()

# %%
dc.fit(X_train, y_train_c)
dc.score(X_test, y_test_c)
# Out:
# 0.6936502712515792

# %%
print(lr.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(lr.summary())
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'
