# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import norm, zscore, t, ttest_ind, permutation_test, ttest_rel, ttest_1samp
from statsmodels.stats.weightstats import ztest
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


sns.set_theme(
    style='whitegrid',       # 배경 스타일 (grid 포함)
    font='BM Hanna Pro',     # 폰트
    rc={
        'axes.unicode_minus': False,  # 마이너스 기호 깨짐 방지
        'figure.figsize': (12, 6),    # 그래프 크기 설정
        'axes.labelsize': 14,         # 축 레이블 크기
        'xtick.labelsize': 12,        # x축 눈금 크기
        'ytick.labelsize': 12,        # y축 눈금 크기
        'legend.fontsize': 12,        # 범례 폰트 크기
        'axes.titleweight': 'bold',   # 제목 굵게
        'axes.titlesize': 16          # 제목 크기
    }
)

# %config InlineBackend.figure_format = 'retina'

# %%
ns_book7 = pd.read_csv("ns_book7.csv", low_memory=False)
ns_book7
# Out:
#             번호                    도서명                저자  ... 도서권수  대출건수        등록일자
# 0            1                인공지능과 흙            김동훈 지음  ...    1     0  2021-03-19
# 1            2           가짜 행복 권하는 사회            김태형 지음  ...    1     0  2021-03-19
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음  ...    1     0  2021-03-19
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  ...    1     0  2021-03-19
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음  ...    1     0  2021-03-19
# ...        ...                    ...               ...  ...  ...   ...         ...
# 376765  401674            소설의 사회사 비교론            조동일 지음  ...    1     0  1970-01-01
# 376766  401677                    큰오빠            박정근 지음  ...    2     0  1970-01-01
# 376767  401678                韓國現代詩大系            채만묵 編著  ...    1     0  1970-01-01
# 376768  401679                  뉴 웨이브        제임스 모나코 지음  ...    1     0  1970-01-01
# 376769  401681           독일 문학과 세계 문학            吳漢鎭 編著  ...    2     0  1970-01-01
#
# [376770 rows x 13 columns]

# %%
train_set, test_set = train_test_split(ns_book7, random_state=42)

# %%
print(len(train_set), len(test_set))
# Out:
# 282577 94193

# %%
X_train = train_set[['도서권수']]
y_train = train_set['대출건수']

print(X_train.shape, y_train.shape)
# Out:
# (282577, 1) (282577,)
